# %% [markdown]
# In this file, I will attempt to predict data also using coordinates of the grenade detonation - due to the nature of the game, maps have specific spots where specific grenades are meant to detonate - smoke grenades blocking vision in passages, bombsites and sniping spots, molotovs blocking the passage, flashbangs exploding inside a room where people are expected to be etc.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn as sk

# %%
inferno = pd.read_csv("data/train-grenades-de_inferno.csv")
mirage = pd.read_csv("data/train-grenades-de_mirage.csv")
inferno
# Out:
#      Unnamed: 0  demo_id  demo_round_id  round_start_tick  weapon_fire_id  \
# 0             0     5158          46311            159689         6573932
# 1             1     5595          55563            397002         7899867
# 2             2     5596          55589            305379         7903151
# 3             3     5596          55595            397002         7904064
# 4             4      788          42597             71501         6039404
# ..          ...      ...            ...               ...             ...
# 349         349      596          42744             45262         6063867
# 350         350     5596          55582            187969         7902073
# 351         351     5452          51765             93628         7371564
# 352         352      645          42494            370398         6024136
# 353         353     5546          54182            221771         7701630
#
#     team  detonation_raw_x  detonation_raw_y  detonation_raw_z  \
# 0     CT          448.4950          3380.300          222.4680
# 1      T          778.6860          2274.620          137.7930
# 2      T         1447.9700           896.635          144.4740
# 3      T         2717.1800           318.481          552.7410
# 4      T          313.6380          2291.220          396.4490
# ..   ...               ...               ...               ...
# 349    T         2479.9600          -107.194           86.0312
# 350    T          490.8890          3166.080          162.0310
# 351    T          982.5730          2677.020          129.9930
# 352    T          -13.2019          1426.310          102.8550
# 353    T          988.9120          2652.220          132.0620
#
#      throw_from_raw_x  throw_from_raw_y  throw_from_raw_z  throw_tick  \
# 0          864.899658       2389.010254        144.062393       13344
# 1          455.041687       3182.332275        160.031250       11044
# 2         -279.968750       -268.968750         29.181963        3193
# 3         1880.825562        571.397339        222.031250       10406
# 4         1166.624634       2799.950684        127.641594        2873
# ..                ...               ...               ...         ...
# 349       1431.441772        130.297836        127.680000       10722
# 350        110.810173       1569.611816        132.013687       11141
# 351        611.807983       1969.810059        130.363892        8960
# 352       1263.402222       2981.905029        135.901749        7269
# 353        647.272644       2040.791626        132.831039        6843
#
#      detonation_tick  LABEL       TYPE    map_name
# 0            13566.0   True  flashbang  de_inferno
# 1            11352.0   True      smoke  de_inferno
# 2             3871.0   True      smoke  de_inferno
# 3            10628.0   True  flashbang  de_inferno
# 4             3095.0   True  flashbang  de_inferno
# ..               ...    ...        ...         ...
# 349          10952.0   True    molotov  de_inferno
# 350          11843.0   True      smoke  de_inferno
# 351           9196.0   True      smoke  de_inferno
# 352           8025.0  False      smoke  de_inferno
# 353           7081.0  False      smoke  de_inferno
#
# [354 rows x 17 columns]

# %%
grenades = pd.concat([inferno, mirage], ignore_index = True)
grenades = grenades.loc[:, ['team','detonation_raw_x','detonation_raw_y', 'detonation_raw_z','throw_from_raw_x', 'throw_from_raw_y', 'throw_from_raw_z', 'throw_tick', 'detonation_tick', 'LABEL', 'TYPE', 'map_name']]
grenades
# Out:
#     team  detonation_raw_x  detonation_raw_y  detonation_raw_z  \
# 0     CT           448.495          3380.300          222.4680
# 1      T           778.686          2274.620          137.7930
# 2      T          1447.970           896.635          144.4740
# 3      T          2717.180           318.481          552.7410
# 4      T           313.638          2291.220          396.4490
# ..   ...               ...               ...               ...
# 719    T         -1462.400           728.349          -45.9688
# 720   CT          -756.819         -2198.980         -159.1930
# 721   CT          -696.054         -1541.940           59.4860
# 722   CT           529.241         -1621.910         -262.0000
# 723   CT         -1151.840          -628.823         -165.9690
#
#      throw_from_raw_x  throw_from_raw_y  throw_from_raw_z  throw_tick  \
# 0          864.899658       2389.010254        144.062393       13344
# 1          455.041687       3182.332275        160.031250       11044
# 2         -279.968750       -268.968750         29.181963        3193
# 3         1880.825562        571.397339        222.031250       10406
# 4         1166.624634       2799.950684        127.641594        2873
# ..                ...               ...               ...         ...
# 719      -1959.668213        704.495361        -47.968750       14328
# 720       -593.158081      -1179.779297       -167.968750        9318
# 721       -918.049866      -2595.171631       -167.968750       11433
# 722          5.098903      -1576.270996       -170.078476        3034
# 723       1421.914795         34.830582       -163.396576        5760
#
#      detonation_tick  LABEL       TYPE    map_name
# 0            13566.0   True  flashbang  de_inferno
# 1            11352.0   True      smoke  de_inferno
# 2             3871.0   True      smoke  de_inferno
# 3            10628.0   True  flashbang  de_inferno
# 4             3095.0   True  flashbang  de_inferno
# ..               ...    ...        ...         ...
# 719          14564.0   True      smoke   de_mirage
# 720           9540.0  False  flashbang   de_mirage
# 721          11657.0   True  flashbang   de_mirage
# 722           3342.0   True      smoke   de_mirage
# 723           6644.0   True      smoke   de_mirage
#
# [724 rows x 12 columns]

# %% [markdown]
# Here we can see the distribution of grenade explosions among coordinates (yellow dots are 'valid' grenades, purple are 'invalid'). We can see clusters of yellow dots, and more spread out distribution of purple dots, which tells us that locations of the detonation might actually mean something.

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
cax = ax.scatter(grenades['detonation_raw_x'], grenades['detonation_raw_y'],
                 grenades['detonation_raw_z'], c=grenades['LABEL'])
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_zlabel('$z$')
fig.colorbar(cax)
plt.show()

# %% [markdown]
# Now we create data as in the other notebook, but also add the detonation coords.

# %%
grenades['throw_dist'] = np.sqrt((grenades['throw_from_raw_x'] - grenades['detonation_raw_x'])**2 + 
                                   (grenades['throw_from_raw_y'] - grenades['detonation_raw_y'])**2 +
                                   (grenades['throw_from_raw_z'] - grenades['detonation_raw_z'])**2)
grenades = grenades[['detonation_raw_x', 'detonation_raw_y', 'detonation_raw_z',
                         'team', 'LABEL', 'TYPE','map_name','throw_tick', 'throw_dist']]
grenades
# Out:
#      detonation_raw_x  detonation_raw_y  detonation_raw_z team  LABEL  \
# 0             448.495          3380.300          222.4680   CT   True
# 1             778.686          2274.620          137.7930    T   True
# 2            1447.970           896.635          144.4740    T   True
# 3            2717.180           318.481          552.7410    T   True
# 4             313.638          2291.220          396.4490    T   True
# ..                ...               ...               ...  ...    ...
# 719         -1462.400           728.349          -45.9688    T   True
# 720          -756.819         -2198.980         -159.1930   CT  False
# 721          -696.054         -1541.940           59.4860   CT   True
# 722           529.241         -1621.910         -262.0000   CT   True
# 723         -1151.840          -628.823         -165.9690   CT   True
#
#           TYPE    map_name  throw_tick   throw_dist
# 0    flashbang  de_inferno       13344  1078.051779
# 1        smoke  de_inferno       11044   963.940743
# 2        smoke  de_inferno        3193  2087.509684
# 3    flashbang  de_inferno       10406   934.250694
# 4    flashbang  de_inferno        2873  1028.907444
# ..         ...         ...         ...          ...
# 719      smoke   de_mirage       14328   497.844023
# 720  flashbang   de_mirage        9318  1032.294524
# 721  flashbang   de_mirage       11433  1100.143034
# 722      smoke   de_mirage        3034   534.094957
# 723      smoke   de_mirage        5760  2657.942144
#
# [724 rows x 9 columns]

# %%
grenades['LABEL'] = grenades['LABEL'].apply(lambda x: 1 if x is True else 0)
# Out:
# <ipython-input-6-816887519a96>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grenades['LABEL'] = grenades['LABEL'].apply(lambda x: 1 if x is True else 0)

# %%
dummies = pd.get_dummies(grenades[['team', 'TYPE', 'map_name']])
dummies
# Out:
#      team_CT  team_T  TYPE_flashbang  TYPE_molotov  TYPE_smoke  \
# 0          1       0               1             0           0
# 1          0       1               0             0           1
# 2          0       1               0             0           1
# 3          0       1               1             0           0
# 4          0       1               1             0           0
# ..       ...     ...             ...           ...         ...
# 719        0       1               0             0           1
# 720        1       0               1             0           0
# 721        1       0               1             0           0
# 722        1       0               0             0           1
# 723        1       0               0             0           1
#
#      map_name_de_inferno  map_name_de_mirage
# 0                      1                   0
# 1                      1                   0
# 2                      1                   0
# 3                      1                   0
# 4                      1                   0
# ..                   ...                 ...
# 719                    0                   1
# 720                    0                   1
# 721                    0                   1
# 722                    0                   1
# 723                    0                   1
#
# [724 rows x 7 columns]

# %%
grenades_num = grenades[['detonation_raw_x', 'detonation_raw_y', 'detonation_raw_z', 'throw_tick', 'throw_dist']]
grenades_num
# Out:
#      detonation_raw_x  detonation_raw_y  detonation_raw_z  throw_tick  \
# 0             448.495          3380.300          222.4680       13344
# 1             778.686          2274.620          137.7930       11044
# 2            1447.970           896.635          144.4740        3193
# 3            2717.180           318.481          552.7410       10406
# 4             313.638          2291.220          396.4490        2873
# ..                ...               ...               ...         ...
# 719         -1462.400           728.349          -45.9688       14328
# 720          -756.819         -2198.980         -159.1930        9318
# 721          -696.054         -1541.940           59.4860       11433
# 722           529.241         -1621.910         -262.0000        3034
# 723         -1151.840          -628.823         -165.9690        5760
#
#       throw_dist
# 0    1078.051779
# 1     963.940743
# 2    2087.509684
# 3     934.250694
# 4    1028.907444
# ..           ...
# 719   497.844023
# 720  1032.294524
# 721  1100.143034
# 722   534.094957
# 723  2657.942144
#
# [724 rows x 5 columns]

# %%
X = dummies.join(grenades_num)
Y = grenades["LABEL"]

# %%
X["throw_tick_norm"] = np.log(X["throw_tick"] + 1)
X["throw_tick_norm"].hist()
# Out:
# <AxesSubplot:>

# %%
X.drop("throw_tick",1,inplace=True)
X
# Out:
#      team_CT  team_T  TYPE_flashbang  TYPE_molotov  TYPE_smoke  \
# 0          1       0               1             0           0
# 1          0       1               0             0           1
# 2          0       1               0             0           1
# 3          0       1               1             0           0
# 4          0       1               1             0           0
# ..       ...     ...             ...           ...         ...
# 719        0       1               0             0           1
# 720        1       0               1             0           0
# 721        1       0               1             0           0
# 722        1       0               0             0           1
# 723        1       0               0             0           1
#
#      map_name_de_inferno  map_name_de_mirage  detonation_raw_x  \
# 0                      1                   0           448.495
# 1                      1                   0           778.686
# 2                      1                   0          1447.970
# 3                      1                   0          2717.180
# 4                      1                   0           313.638
# ..                   ...                 ...               ...
# 719                    0                   1         -1462.400
# 720                    0                   1          -756.819
# 721                    0                   1          -696.054
# 722                    0                   1           529.241
# 723                    0                   1         -1151.840
#
#      detonation_raw_y  detonation_raw_z   throw_dist  throw_tick_norm
# 0            3380.300          222.4680  1078.051779         9.498897
# 1            2274.620          137.7930   963.940743         9.309733
# 2             896.635          144.4740  2087.509684         8.069029
# 3             318.481          552.7410   934.250694         9.250234
# 4            2291.220          396.4490  1028.907444         7.963460
# ..                ...               ...          ...              ...
# 719           728.349          -45.9688   497.844023         9.570041
# 720         -2198.980         -159.1930  1032.294524         9.139811
# 721         -1541.940           59.4860  1100.143034         9.344347
# 722         -1621.910         -262.0000   534.094957         8.017967
# 723          -628.823         -165.9690  2657.942144         8.658866
#
# [724 rows x 12 columns]

# %% [markdown]
# Now we want to see the distribution of coords of detonations to know, if we can normalize it.

# %%
X["detonation_raw_x"].hist()
# Out:
# <AxesSubplot:>

# %%
X["detonation_raw_y"].hist()
# Out:
# <AxesSubplot:>

# %%
X["detonation_raw_z"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# The distributions are more or less normal, so we can normalize them. throw_dist and throw_tick_norm have normal distributions, as shown in the other notebook.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = X.copy()
X_scaled[["detonation_raw_x", "detonation_raw_y", "detonation_raw_z",
          "throw_dist", "throw_tick_norm"]] = scaler.fit_transform(X_scaled[["detonation_raw_x",
                                                                             "detonation_raw_y", "detonation_raw_z", 
                                                                             "throw_dist", "throw_tick_norm"]])
X_scaled
# Out:
#      team_CT  team_T  TYPE_flashbang  TYPE_molotov  TYPE_smoke  \
# 0          1       0               1             0           0
# 1          0       1               0             0           1
# 2          0       1               0             0           1
# 3          0       1               1             0           0
# 4          0       1               1             0           0
# ..       ...     ...             ...           ...         ...
# 719        0       1               0             0           1
# 720        1       0               1             0           0
# 721        1       0               1             0           0
# 722        1       0               0             0           1
# 723        1       0               0             0           1
#
#      map_name_de_inferno  map_name_de_mirage  detonation_raw_x  \
# 0                      1                   0          0.263262
# 1                      1                   0          0.562037
# 2                      1                   0          1.167643
# 3                      1                   0          2.316096
# 4                      1                   0          0.141236
# ..                   ...                 ...               ...
# 719                    0                   1         -1.465824
# 720                    0                   1         -0.827374
# 721                    0                   1         -0.772391
# 722                    0                   1          0.336325
# 723                    0                   1         -1.184812
#
#      detonation_raw_y  detonation_raw_z  throw_dist  throw_tick_norm
# 0            2.162695          0.686814    0.089648         1.472557
# 1            1.415350          0.300432   -0.113771         1.145835
# 2            0.483951          0.330918    1.889142        -0.997096
# 3            0.093169          2.193889   -0.166697         1.043068
# 4            1.426570          1.480710    0.002041        -1.179434
# ..                ...               ...         ...              ...
# 719          0.370204         -0.538095   -0.944650         1.595435
# 720         -1.608419         -1.054750    0.008079         0.852346
# 721         -1.164316         -0.056892    0.129028         1.205619
# 722         -1.218369         -1.523870   -0.880028        -1.085291
# 723         -0.547128         -1.085670    2.906014         0.021665
#
# [724 rows x 12 columns]

# %%
X_and_Y = X_scaled.join(Y)
X_and_Y
# Out:
#      team_CT  team_T  TYPE_flashbang  TYPE_molotov  TYPE_smoke  \
# 0          1       0               1             0           0
# 1          0       1               0             0           1
# 2          0       1               0             0           1
# 3          0       1               1             0           0
# 4          0       1               1             0           0
# ..       ...     ...             ...           ...         ...
# 719        0       1               0             0           1
# 720        1       0               1             0           0
# 721        1       0               1             0           0
# 722        1       0               0             0           1
# 723        1       0               0             0           1
#
#      map_name_de_inferno  map_name_de_mirage  detonation_raw_x  \
# 0                      1                   0          0.263262
# 1                      1                   0          0.562037
# 2                      1                   0          1.167643
# 3                      1                   0          2.316096
# 4                      1                   0          0.141236
# ..                   ...                 ...               ...
# 719                    0                   1         -1.465824
# 720                    0                   1         -0.827374
# 721                    0                   1         -0.772391
# 722                    0                   1          0.336325
# 723                    0                   1         -1.184812
#
#      detonation_raw_y  detonation_raw_z  throw_dist  throw_tick_norm  LABEL
# 0            2.162695          0.686814    0.089648         1.472557      1
# 1            1.415350          0.300432   -0.113771         1.145835      1
# 2            0.483951          0.330918    1.889142        -0.997096      1
# 3            0.093169          2.193889   -0.166697         1.043068      1
# 4            1.426570          1.480710    0.002041        -1.179434      1
# ..                ...               ...         ...              ...    ...
# 719          0.370204         -0.538095   -0.944650         1.595435      1
# 720         -1.608419         -1.054750    0.008079         0.852346      0
# 721         -1.164316         -0.056892    0.129028         1.205619      1
# 722         -1.218369         -1.523870   -0.880028        -1.085291      1
# 723         -0.547128         -1.085670    2.906014         0.021665      1
#
# [724 rows x 13 columns]

# %% [markdown]
# I decided to create a machine learning model, after some experimenting this one turned out to yield the best results.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import StratifiedKFold
from keras.optimizers import SGD
from keras.layers import Dropout
import tensorflow as tf
def create_baseline():
	
	model = Sequential()
	model.add(Dense(32, input_dim=12, activation='relu'))
	model.add(Dropout(0.4))
	model.add(Dense(16, activation='relu'))
	model.add(Dense(8, activation='relu'))
	model.add(Dense(1, activation='sigmoid'))
	adam=tf.keras.optimizers.Adam(learning_rate=0.001)
	model.compile(loss='binary_crossentropy', optimizer = adam, metrics=['accuracy'])
	return model

# %% [markdown]
# Now the data will be split into two sets - 90% of the 'invalid' grenades and 28% of the 'valid' ones are given to the model. This limitation of data is so that there is about 50% of each class in the set, and I also want to prevent overfitting, which would happen if I fed the entire dataset to the model - especially, that the test is taken from the train data. Overfitting would yield the best result, but it is not the point of a prediction model.

# %%
from keras.callbacks import EarlyStopping
early_stopping_monitor = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0,
    patience=50,
    verbose=0,
    mode='auto',
    baseline=None,
    restore_best_weights=True
)

X_a_Y_t = X_and_Y.loc[X_and_Y["LABEL"] == 1].sample(frac=0.28)
Y_t = X_a_Y_t["LABEL"]
X_t = X_a_Y_t.drop("LABEL", axis=1)

X_a_Y_f = X_and_Y.loc[X_and_Y["LABEL"] == 0].sample(frac=0.9)
Y_f = X_a_Y_f["LABEL"]
X_f = X_a_Y_f.drop("LABEL", axis=1)

X_even = X_t.append(X_f)
Y_even = Y_t.append(Y_f)

estimator = KerasClassifier(build_fn=create_baseline, epochs=500, batch_size=8, verbose=0)
history = estimator.fit(X_even, Y_even, verbose=2, validation_split = 0.1, callbacks=[early_stopping_monitor])
# Out:
# Epoch 1/500
# 34/34 - 0s - loss: 0.7072 - accuracy: 0.5113 - val_loss: 0.8821 - val_accuracy: 0.1000
# Epoch 2/500
# 34/34 - 0s - loss: 0.6809 - accuracy: 0.5752 - val_loss: 0.9562 - val_accuracy: 0.0000e+00
# Epoch 3/500
# 34/34 - 0s - loss: 0.6651 - accuracy: 0.5752 - val_loss: 0.9630 - val_accuracy: 0.0000e+00
# Epoch 4/500
# 34/34 - 0s - loss: 0.6608 - accuracy: 0.6128 - val_loss: 1.0088 - val_accuracy: 0.0000e+00
# Epoch 5/500
# 34/34 - 0s - loss: 0.6730 - accuracy: 0.5940 - val_loss: 0.9685 - val_accuracy: 0.0000e+00
# Epoch 6/500
# 34/34 - 0s - loss: 0.6778 - accuracy: 0.5902 - val_loss: 0.9847 - val_accuracy: 0.0000e+00
# Epoch 7/500
# 34/34 - 0s - loss: 0.6697 - accuracy: 0.6203 - val_loss: 0.9479 - val_accuracy: 0.0667
# Epoch 8/500
# 34/34 - 0s - loss: 0.6591 - accuracy: 0.6128 - val_loss: 0.9734 - val_accuracy: 0.0667
# Epoch 9/500
# 34/34 - 0s - loss: 0.6604 - accuracy: 0.6203 - val_loss: 0.9920 - val_accuracy: 0.0667
# Epoch 10/500
# 34/34 - 0s - loss: 0.6502 - accuracy: 0.6353 - val_loss: 0.9997 - val_accuracy: 0.0667
# Epoch 11/500
# 34/34 - 0s - loss: 0.6615 - accuracy: 0.6316 - val_loss: 0.9932 - val_accuracy: 0.0667
# Epoch 12/500
# 34/34 - 0s - loss: 0.6525 - accuracy: 0.6316 - val_loss: 1.0438 - val_accuracy: 0.0667
# Epoch 13/500
# 34/34 - 0s - loss: 0.6470 - accuracy: 0.6241 - val_loss: 0.9978 - val_accuracy: 0.0667
# Epoch 14/500
# 34/34 - 0s - loss: 0.6458 - accuracy: 0.6429 - val_loss: 1.0176 - val_accuracy: 0.0667
# Epoch 15/500
# 34/34 - 0s - loss: 0.6370 - accuracy: 0.6391 - val_loss: 1.0426 - val_accuracy: 0.0667
# Epoch 16/500
# 34/34 - 0s - loss: 0.6528 - accuracy: 0.6165 - val_loss: 1.0176 - val_accuracy: 0.1333
# Epoch 17/500
# 34/34 - 0s - loss: 0.6388 - accuracy: 0.6353 - val_loss: 1.0093 - val_accuracy: 0.1333
# Epoch 18/500
# 34/34 - 0s - loss: 0.6392 - accuracy: 0.6504 - val_loss: 1.1012 - val_accuracy: 0.0667
# Epoch 19/500
# 34/34 - 0s - loss: 0.6299 - accuracy: 0.6466 - val_loss: 1.0512 - val_accuracy: 0.1000
# Epoch 20/500
# 34/34 - 0s - loss: 0.6273 - accuracy: 0.6353 - val_loss: 1.0349 - val_accuracy: 0.1333
# Epoch 21/500
# 34/34 - 0s - loss: 0.6424 - accuracy: 0.6165 - val_loss: 1.0815 - val_accuracy: 0.1333
# Epoch 22/500
# 34/34 - 0s - loss: 0.6462 - accuracy: 0.6353 - val_loss: 1.0770 - val_accuracy: 0.1000
# Epoch 23/500
# 34/34 - 0s - loss: 0.6486 - accuracy: 0.6203 - val_loss: 1.0399 - val_accuracy: 0.1333
# Epoch 24/500
# 34/34 - 0s - loss: 0.6332 - accuracy: 0.6429 - val_loss: 1.0497 - val_accuracy: 0.1333
# Epoch 25/500
# 34/34 - 0s - loss: 0.6326 - accuracy: 0.6241 - val_loss: 1.0545 - val_accuracy: 0.1000
# Epoch 26/500
# 34/34 - 0s - loss: 0.6412 - accuracy: 0.6466 - val_loss: 1.0405 - val_accuracy: 0.1000
# Epoch 27/500
# 34/34 - 0s - loss: 0.6305 - accuracy: 0.6541 - val_loss: 1.0413 - val_accuracy: 0.1000
# Epoch 28/500
# 34/34 - 0s - loss: 0.6287 - accuracy: 0.6466 - val_loss: 0.9992 - val_accuracy: 0.1667
# Epoch 29/500
# 34/34 - 0s - loss: 0.6170 - accuracy: 0.6278 - val_loss: 1.0209 - val_accuracy: 0.1667
# Epoch 30/500
# 34/34 - 0s - loss: 0.6159 - accuracy: 0.6429 - val_loss: 1.0721 - val_accuracy: 0.1667
# Epoch 31/500
# 34/34 - 0s - loss: 0.6192 - accuracy: 0.6429 - val_loss: 1.0623 - val_accuracy: 0.1667
# Epoch 32/500
# 34/34 - 0s - loss: 0.6119 - accuracy: 0.6917 - val_loss: 1.0633 - val_accuracy: 0.1333
# Epoch 33/500
# 34/34 - 0s - loss: 0.6106 - accuracy: 0.6579 - val_loss: 1.0187 - val_accuracy: 0.1667
# Epoch 34/500
# 34/34 - 0s - loss: 0.6203 - accuracy: 0.6316 - val_loss: 1.0206 - val_accuracy: 0.1667
# Epoch 35/500
# 34/34 - 0s - loss: 0.6043 - accuracy: 0.6654 - val_loss: 1.1008 - val_accuracy: 0.1333
# Epoch 36/500
# 34/34 - 0s - loss: 0.6093 - accuracy: 0.6466 - val_loss: 1.0017 - val_accuracy: 0.1667
# Epoch 37/500
# 34/34 - 0s - loss: 0.6181 - accuracy: 0.6654 - val_loss: 1.0775 - val_accuracy: 0.1667
# Epoch 38/500
# 34/34 - 0s - loss: 0.6098 - accuracy: 0.6504 - val_loss: 1.1186 - val_accuracy: 0.1333
# Epoch 39/500
# 34/34 - 0s - loss: 0.5982 - accuracy: 0.6729 - val_loss: 1.0578 - val_accuracy: 0.1667
# Epoch 40/500
# 34/34 - 0s - loss: 0.6374 - accuracy: 0.6278 - val_loss: 0.9835 - val_accuracy: 0.1667
# Epoch 41/500
# 34/34 - 0s - loss: 0.6126 - accuracy: 0.7030 - val_loss: 1.0619 - val_accuracy: 0.1333
# Epoch 42/500
# 34/34 - 0s - loss: 0.6318 - accuracy: 0.6541 - val_loss: 1.0654 - val_accuracy: 0.1333
# Epoch 43/500
# 34/34 - 0s - loss: 0.6139 - accuracy: 0.6353 - val_loss: 1.0654 - val_accuracy: 0.1333
# Epoch 44/500
# 34/34 - 0s - loss: 0.6065 - accuracy: 0.6466 - val_loss: 1.0683 - val_accuracy: 0.1333
# Epoch 45/500
# 34/34 - 0s - loss: 0.6005 - accuracy: 0.6541 - val_loss: 1.0433 - val_accuracy: 0.1333
# Epoch 46/500
# 34/34 - 0s - loss: 0.6081 - accuracy: 0.6917 - val_loss: 1.0025 - val_accuracy: 0.1667
# Epoch 47/500
# 34/34 - 0s - loss: 0.6023 - accuracy: 0.6654 - val_loss: 1.0014 - val_accuracy: 0.1667
# Epoch 48/500
# 34/34 - 0s - loss: 0.6165 - accuracy: 0.6692 - val_loss: 1.0294 - val_accuracy: 0.1667
# Epoch 49/500
# 34/34 - 0s - loss: 0.5937 - accuracy: 0.6429 - val_loss: 1.1065 - val_accuracy: 0.1333
# Epoch 50/500
# 34/34 - 0s - loss: 0.5908 - accuracy: 0.6805 - val_loss: 1.0696 - val_accuracy: 0.1333
# Epoch 51/500
# 34/34 - 0s - loss: 0.5954 - accuracy: 0.6579 - val_loss: 0.9837 - val_accuracy: 0.1333
# Epoch 52/500
# 34/34 - 0s - loss: 0.6130 - accuracy: 0.6654 - val_loss: 1.0689 - val_accuracy: 0.1333
# Epoch 53/500
# 34/34 - 0s - loss: 0.5830 - accuracy: 0.6729 - val_loss: 1.0832 - val_accuracy: 0.1333
# Epoch 54/500
# 34/34 - 0s - loss: 0.5868 - accuracy: 0.6692 - val_loss: 1.0536 - val_accuracy: 0.1333
# Epoch 55/500
# 34/34 - 0s - loss: 0.5825 - accuracy: 0.6654 - val_loss: 1.0856 - val_accuracy: 0.1667
# Epoch 56/500
# 34/34 - 0s - loss: 0.5754 - accuracy: 0.6617 - val_loss: 1.0444 - val_accuracy: 0.1667
# Epoch 57/500
# 34/34 - 0s - loss: 0.6014 - accuracy: 0.6654 - val_loss: 1.0954 - val_accuracy: 0.1667
# Epoch 58/500
# 34/34 - 0s - loss: 0.5932 - accuracy: 0.6541 - val_loss: 1.0380 - val_accuracy: 0.1667
# Epoch 59/500
# 34/34 - 0s - loss: 0.5741 - accuracy: 0.6805 - val_loss: 0.9941 - val_accuracy: 0.2333
# Epoch 60/500
# 34/34 - 0s - loss: 0.5730 - accuracy: 0.6805 - val_loss: 1.0983 - val_accuracy: 0.2000
# Epoch 61/500
# 34/34 - 0s - loss: 0.5897 - accuracy: 0.6692 - val_loss: 1.0574 - val_accuracy: 0.2000
# Epoch 62/500
# 34/34 - 0s - loss: 0.5687 - accuracy: 0.7068 - val_loss: 1.0903 - val_accuracy: 0.2333
# Epoch 63/500
# 34/34 - 0s - loss: 0.5626 - accuracy: 0.6992 - val_loss: 1.0895 - val_accuracy: 0.2333
# Epoch 64/500
# 34/34 - 0s - loss: 0.6002 - accuracy: 0.6805 - val_loss: 1.0611 - val_accuracy: 0.2333
# Epoch 65/500
# 34/34 - 0s - loss: 0.5639 - accuracy: 0.7068 - val_loss: 1.0192 - val_accuracy: 0.2667
# Epoch 66/500
# 34/34 - 0s - loss: 0.5467 - accuracy: 0.7180 - val_loss: 1.0622 - val_accuracy: 0.2667
# Epoch 67/500
# 34/34 - 0s - loss: 0.5641 - accuracy: 0.7030 - val_loss: 1.1202 - val_accuracy: 0.2000
# Epoch 68/500
# 34/34 - 0s - loss: 0.5746 - accuracy: 0.6654 - val_loss: 1.1067 - val_accuracy: 0.2000
# Epoch 69/500
# 34/34 - 0s - loss: 0.5738 - accuracy: 0.6880 - val_loss: 1.1195 - val_accuracy: 0.2000
# Epoch 70/500
# 34/34 - 0s - loss: 0.5936 - accuracy: 0.6579 - val_loss: 1.1335 - val_accuracy: 0.2000
# Epoch 71/500
# 34/34 - 0s - loss: 0.5394 - accuracy: 0.7444 - val_loss: 1.0609 - val_accuracy: 0.2333
# Epoch 72/500
# 34/34 - 0s - loss: 0.5768 - accuracy: 0.6955 - val_loss: 1.1352 - val_accuracy: 0.2000
# Epoch 73/500
# 34/34 - 0s - loss: 0.5474 - accuracy: 0.7180 - val_loss: 1.1072 - val_accuracy: 0.2333
# Epoch 74/500
# 34/34 - 0s - loss: 0.5402 - accuracy: 0.7256 - val_loss: 1.1186 - val_accuracy: 0.2667
# Epoch 75/500
# 34/34 - 0s - loss: 0.5500 - accuracy: 0.7105 - val_loss: 1.0428 - val_accuracy: 0.2667
# Epoch 76/500
# 34/34 - 0s - loss: 0.5925 - accuracy: 0.6504 - val_loss: 1.0777 - val_accuracy: 0.2667
# Epoch 77/500
# 34/34 - 0s - loss: 0.5657 - accuracy: 0.6880 - val_loss: 1.0972 - val_accuracy: 0.2667
# Epoch 78/500
# 34/34 - 0s - loss: 0.5706 - accuracy: 0.6842 - val_loss: 1.0812 - val_accuracy: 0.2667
# Epoch 79/500
# 34/34 - 0s - loss: 0.5476 - accuracy: 0.7293 - val_loss: 1.1021 - val_accuracy: 0.2667
# Epoch 80/500
# 34/34 - 0s - loss: 0.5725 - accuracy: 0.6842 - val_loss: 1.1249 - val_accuracy: 0.2333
# Epoch 81/500
# 34/34 - 0s - loss: 0.5623 - accuracy: 0.7143 - val_loss: 1.0624 - val_accuracy: 0.2333
# Epoch 82/500
# 34/34 - 0s - loss: 0.5802 - accuracy: 0.6692 - val_loss: 1.0705 - val_accuracy: 0.2333
# Epoch 83/500
# 34/34 - 0s - loss: 0.5323 - accuracy: 0.7556 - val_loss: 1.0612 - val_accuracy: 0.2667
# Epoch 84/500
# 34/34 - 0s - loss: 0.5458 - accuracy: 0.7068 - val_loss: 1.1392 - val_accuracy: 0.2333
# Epoch 85/500
# 34/34 - 0s - loss: 0.5675 - accuracy: 0.6842 - val_loss: 1.0342 - val_accuracy: 0.3000
# Epoch 86/500
# 34/34 - 0s - loss: 0.5642 - accuracy: 0.6842 - val_loss: 1.0581 - val_accuracy: 0.2667
# Epoch 87/500
# 34/34 - 0s - loss: 0.5806 - accuracy: 0.6880 - val_loss: 1.0999 - val_accuracy: 0.2333
# Epoch 88/500
# 34/34 - 0s - loss: 0.5445 - accuracy: 0.6805 - val_loss: 0.9433 - val_accuracy: 0.2667
# Epoch 89/500
# 34/34 - 0s - loss: 0.5687 - accuracy: 0.7030 - val_loss: 1.0365 - val_accuracy: 0.2333
# Epoch 90/500
# 34/34 - 0s - loss: 0.5436 - accuracy: 0.6992 - val_loss: 1.0797 - val_accuracy: 0.2667
# Epoch 91/500
# 34/34 - 0s - loss: 0.5270 - accuracy: 0.7030 - val_loss: 1.0776 - val_accuracy: 0.2667
# Epoch 92/500
# 34/34 - 0s - loss: 0.5676 - accuracy: 0.6880 - val_loss: 1.1290 - val_accuracy: 0.3000
# Epoch 93/500
# 34/34 - 0s - loss: 0.5650 - accuracy: 0.7030 - val_loss: 1.1447 - val_accuracy: 0.3000
# Epoch 94/500
# 34/34 - 0s - loss: 0.5477 - accuracy: 0.6992 - val_loss: 1.1215 - val_accuracy: 0.3000
# Epoch 95/500
# 34/34 - 0s - loss: 0.5439 - accuracy: 0.7256 - val_loss: 1.0936 - val_accuracy: 0.3000
# Epoch 96/500
# 34/34 - 0s - loss: 0.5365 - accuracy: 0.7368 - val_loss: 1.0824 - val_accuracy: 0.3000
# Epoch 97/500
# 34/34 - 0s - loss: 0.5569 - accuracy: 0.7105 - val_loss: 1.1069 - val_accuracy: 0.3000
# Epoch 98/500
# 34/34 - 0s - loss: 0.5412 - accuracy: 0.7256 - val_loss: 1.1081 - val_accuracy: 0.3000
# Epoch 99/500
# 34/34 - 0s - loss: 0.5404 - accuracy: 0.7030 - val_loss: 1.1077 - val_accuracy: 0.3000
# Epoch 100/500
# 34/34 - 0s - loss: 0.5258 - accuracy: 0.7293 - val_loss: 1.0931 - val_accuracy: 0.3000
# Epoch 101/500
# 34/34 - 0s - loss: 0.5112 - accuracy: 0.7180 - val_loss: 1.1755 - val_accuracy: 0.3000
# Epoch 102/500
# 34/34 - 0s - loss: 0.5378 - accuracy: 0.7068 - val_loss: 1.0377 - val_accuracy: 0.3000
# Epoch 103/500
# 34/34 - 0s - loss: 0.5382 - accuracy: 0.6955 - val_loss: 1.1256 - val_accuracy: 0.3000
# Epoch 104/500
# 34/34 - 0s - loss: 0.5391 - accuracy: 0.7180 - val_loss: 1.0779 - val_accuracy: 0.3000
# Epoch 105/500
# 34/34 - 0s - loss: 0.5429 - accuracy: 0.7594 - val_loss: 1.1684 - val_accuracy: 0.3000
# Epoch 106/500
# 34/34 - 0s - loss: 0.5172 - accuracy: 0.7368 - val_loss: 1.1779 - val_accuracy: 0.3000
# Epoch 107/500
# 34/34 - 0s - loss: 0.5647 - accuracy: 0.6917 - val_loss: 1.1230 - val_accuracy: 0.3000
# Epoch 108/500
# 34/34 - 0s - loss: 0.5527 - accuracy: 0.6880 - val_loss: 1.1615 - val_accuracy: 0.2333
# Epoch 109/500
# 34/34 - 0s - loss: 0.4979 - accuracy: 0.7556 - val_loss: 1.1345 - val_accuracy: 0.2333
# Epoch 110/500
# 34/34 - 0s - loss: 0.5457 - accuracy: 0.7068 - val_loss: 1.1558 - val_accuracy: 0.3000
# Epoch 111/500
# 34/34 - 0s - loss: 0.5265 - accuracy: 0.7256 - val_loss: 1.1238 - val_accuracy: 0.3000
# Epoch 112/500
# 34/34 - 0s - loss: 0.5305 - accuracy: 0.6842 - val_loss: 1.2044 - val_accuracy: 0.3000
# Epoch 113/500
# 34/34 - 0s - loss: 0.5325 - accuracy: 0.6842 - val_loss: 1.1508 - val_accuracy: 0.3000
# Epoch 114/500
# 34/34 - 0s - loss: 0.5298 - accuracy: 0.7293 - val_loss: 1.0961 - val_accuracy: 0.3667
# Epoch 115/500
# 34/34 - 0s - loss: 0.4814 - accuracy: 0.7820 - val_loss: 1.1802 - val_accuracy: 0.3333
# Epoch 116/500
# 34/34 - 0s - loss: 0.5424 - accuracy: 0.7068 - val_loss: 1.1458 - val_accuracy: 0.3667
# Epoch 117/500
# 34/34 - 0s - loss: 0.5399 - accuracy: 0.7105 - val_loss: 1.1080 - val_accuracy: 0.4000
# Epoch 118/500
# 34/34 - 0s - loss: 0.5166 - accuracy: 0.7143 - val_loss: 1.1263 - val_accuracy: 0.3333
# Epoch 119/500
# 34/34 - 0s - loss: 0.5120 - accuracy: 0.7218 - val_loss: 1.0732 - val_accuracy: 0.4000
# Epoch 120/500
# 34/34 - 0s - loss: 0.5394 - accuracy: 0.7068 - val_loss: 1.1772 - val_accuracy: 0.3667
# Epoch 121/500
# 34/34 - 0s - loss: 0.5230 - accuracy: 0.7256 - val_loss: 1.0665 - val_accuracy: 0.4000
# Epoch 122/500
# 34/34 - 0s - loss: 0.5019 - accuracy: 0.7256 - val_loss: 1.1759 - val_accuracy: 0.3667
# Epoch 123/500
# 34/34 - 0s - loss: 0.5163 - accuracy: 0.7143 - val_loss: 1.1385 - val_accuracy: 0.3667
# Epoch 124/500
# 34/34 - 0s - loss: 0.5116 - accuracy: 0.7180 - val_loss: 1.1461 - val_accuracy: 0.3667
# Epoch 125/500
# 34/34 - 0s - loss: 0.5048 - accuracy: 0.7556 - val_loss: 1.1685 - val_accuracy: 0.3667
# Epoch 126/500
# 34/34 - 0s - loss: 0.5380 - accuracy: 0.7180 - val_loss: 1.1376 - val_accuracy: 0.3667
# Epoch 127/500
# 34/34 - 0s - loss: 0.5091 - accuracy: 0.7068 - val_loss: 1.1044 - val_accuracy: 0.3667
# Epoch 128/500
# 34/34 - 0s - loss: 0.5130 - accuracy: 0.6955 - val_loss: 1.0942 - val_accuracy: 0.3667
# Epoch 129/500
# 34/34 - 0s - loss: 0.5012 - accuracy: 0.7556 - val_loss: 1.2676 - val_accuracy: 0.3000
# Epoch 130/500
# 34/34 - 0s - loss: 0.5014 - accuracy: 0.7368 - val_loss: 1.1809 - val_accuracy: 0.3333
# Epoch 131/500
# 34/34 - 0s - loss: 0.5204 - accuracy: 0.7293 - val_loss: 1.2475 - val_accuracy: 0.3333
# Epoch 132/500
# 34/34 - 0s - loss: 0.4988 - accuracy: 0.7143 - val_loss: 1.2261 - val_accuracy: 0.3333
# Epoch 133/500
# 34/34 - 0s - loss: 0.4923 - accuracy: 0.7481 - val_loss: 1.1234 - val_accuracy: 0.4333
# Epoch 134/500
# 34/34 - 0s - loss: 0.4842 - accuracy: 0.7368 - val_loss: 1.1706 - val_accuracy: 0.4000
# Epoch 135/500
# 34/34 - 0s - loss: 0.5165 - accuracy: 0.7293 - val_loss: 1.2295 - val_accuracy: 0.3000
# Epoch 136/500
# 34/34 - 0s - loss: 0.5142 - accuracy: 0.7218 - val_loss: 1.1861 - val_accuracy: 0.3333
# Epoch 137/500
# 34/34 - 0s - loss: 0.5049 - accuracy: 0.7368 - val_loss: 1.2109 - val_accuracy: 0.3000
# Epoch 138/500
# 34/34 - 0s - loss: 0.5207 - accuracy: 0.7180 - val_loss: 1.1106 - val_accuracy: 0.4000
# Epoch 139/500
# 34/34 - 0s - loss: 0.5053 - accuracy: 0.7331 - val_loss: 1.1650 - val_accuracy: 0.3667
# Epoch 140/500
# 34/34 - 0s - loss: 0.5269 - accuracy: 0.7143 - val_loss: 1.1745 - val_accuracy: 0.3667
# Epoch 141/500
# 34/34 - 0s - loss: 0.4998 - accuracy: 0.7406 - val_loss: 1.1873 - val_accuracy: 0.3667
# Epoch 142/500
# 34/34 - 0s - loss: 0.5039 - accuracy: 0.7444 - val_loss: 1.2719 - val_accuracy: 0.3333
# Epoch 143/500
# 34/34 - 0s - loss: 0.5141 - accuracy: 0.7030 - val_loss: 1.1760 - val_accuracy: 0.3667
# Epoch 144/500
# 34/34 - 0s - loss: 0.5348 - accuracy: 0.7293 - val_loss: 1.1865 - val_accuracy: 0.4000
# Epoch 145/500
# 34/34 - 0s - loss: 0.5109 - accuracy: 0.7218 - val_loss: 1.2758 - val_accuracy: 0.3667
# Epoch 146/500
# 34/34 - 0s - loss: 0.4986 - accuracy: 0.7481 - val_loss: 1.1158 - val_accuracy: 0.4000
# Epoch 147/500
# 34/34 - 0s - loss: 0.4973 - accuracy: 0.7218 - val_loss: 1.1724 - val_accuracy: 0.4000
# Epoch 148/500
# 34/34 - 0s - loss: 0.5348 - accuracy: 0.7030 - val_loss: 1.2675 - val_accuracy: 0.3667
# Epoch 149/500
# 34/34 - 0s - loss: 0.5057 - accuracy: 0.7331 - val_loss: 1.1354 - val_accuracy: 0.4000
# Epoch 150/500
# 34/34 - 0s - loss: 0.5032 - accuracy: 0.7105 - val_loss: 1.2849 - val_accuracy: 0.3667
# Epoch 151/500
# 34/34 - 0s - loss: 0.4868 - accuracy: 0.7556 - val_loss: 1.1564 - val_accuracy: 0.4000
# Epoch 152/500
# 34/34 - 0s - loss: 0.5045 - accuracy: 0.7030 - val_loss: 1.2022 - val_accuracy: 0.3667
# Epoch 153/500
# 34/34 - 0s - loss: 0.5055 - accuracy: 0.7444 - val_loss: 1.3410 - val_accuracy: 0.3333
# Epoch 154/500
# 34/34 - 0s - loss: 0.5205 - accuracy: 0.7030 - val_loss: 1.1433 - val_accuracy: 0.4000
# Epoch 155/500
# 34/34 - 0s - loss: 0.4884 - accuracy: 0.7444 - val_loss: 1.1767 - val_accuracy: 0.4000
# Epoch 156/500
# 34/34 - 0s - loss: 0.4937 - accuracy: 0.7519 - val_loss: 1.2319 - val_accuracy: 0.3667
# Epoch 157/500
# 34/34 - 0s - loss: 0.4895 - accuracy: 0.7632 - val_loss: 1.2508 - val_accuracy: 0.3333
# Epoch 158/500
# 34/34 - 0s - loss: 0.5274 - accuracy: 0.7256 - val_loss: 1.2085 - val_accuracy: 0.3333
# Epoch 159/500
# 34/34 - 0s - loss: 0.4732 - accuracy: 0.7632 - val_loss: 1.2153 - val_accuracy: 0.3333
# Epoch 160/500
# 34/34 - 0s - loss: 0.4698 - accuracy: 0.7444 - val_loss: 1.2611 - val_accuracy: 0.3333
# Epoch 161/500
# 34/34 - 0s - loss: 0.5168 - accuracy: 0.7293 - val_loss: 1.2236 - val_accuracy: 0.3667
# Epoch 162/500
# 34/34 - 0s - loss: 0.5026 - accuracy: 0.7256 - val_loss: 1.2515 - val_accuracy: 0.3333
# Epoch 163/500
# 34/34 - 0s - loss: 0.4596 - accuracy: 0.7669 - val_loss: 1.3558 - val_accuracy: 0.3333
# Epoch 164/500
# 34/34 - 0s - loss: 0.5195 - accuracy: 0.7105 - val_loss: 1.1723 - val_accuracy: 0.3667
# Epoch 165/500
# 34/34 - 0s - loss: 0.4716 - accuracy: 0.7632 - val_loss: 1.2159 - val_accuracy: 0.3333
# Epoch 166/500
# 34/34 - 0s - loss: 0.4818 - accuracy: 0.7256 - val_loss: 1.3497 - val_accuracy: 0.3667
# Epoch 167/500
# 34/34 - 0s - loss: 0.4866 - accuracy: 0.7519 - val_loss: 1.1564 - val_accuracy: 0.4000
# Epoch 168/500
# 34/34 - 0s - loss: 0.4836 - accuracy: 0.7556 - val_loss: 1.3098 - val_accuracy: 0.3000
# Epoch 169/500
# 34/34 - 0s - loss: 0.4859 - accuracy: 0.7406 - val_loss: 1.3013 - val_accuracy: 0.3333
# Epoch 170/500
# 34/34 - 0s - loss: 0.4693 - accuracy: 0.7481 - val_loss: 1.2142 - val_accuracy: 0.3667
# Epoch 171/500
# 34/34 - 0s - loss: 0.4975 - accuracy: 0.6917 - val_loss: 1.2875 - val_accuracy: 0.3667
# Epoch 172/500
# 34/34 - 0s - loss: 0.4862 - accuracy: 0.7481 - val_loss: 1.3510 - val_accuracy: 0.3667
# Epoch 173/500
# 34/34 - 0s - loss: 0.5028 - accuracy: 0.7481 - val_loss: 1.3219 - val_accuracy: 0.3667
# Epoch 174/500
# 34/34 - 0s - loss: 0.4683 - accuracy: 0.7556 - val_loss: 1.2687 - val_accuracy: 0.3667
# Epoch 175/500
# 34/34 - 0s - loss: 0.4740 - accuracy: 0.7368 - val_loss: 1.2725 - val_accuracy: 0.3667
# Epoch 176/500
# 34/34 - 0s - loss: 0.4619 - accuracy: 0.7632 - val_loss: 1.2120 - val_accuracy: 0.3667
# Epoch 177/500
# 34/34 - 0s - loss: 0.5053 - accuracy: 0.7368 - val_loss: 1.2437 - val_accuracy: 0.3667
# Epoch 178/500
# 34/34 - 0s - loss: 0.4593 - accuracy: 0.7820 - val_loss: 1.1953 - val_accuracy: 0.3667
# Epoch 179/500
# 34/34 - 0s - loss: 0.5059 - accuracy: 0.7406 - val_loss: 1.2757 - val_accuracy: 0.4000
# Epoch 180/500
# 34/34 - 0s - loss: 0.4825 - accuracy: 0.7594 - val_loss: 1.3114 - val_accuracy: 0.3667
# Epoch 181/500
# 34/34 - 0s - loss: 0.4869 - accuracy: 0.7481 - val_loss: 1.0774 - val_accuracy: 0.4000
# Epoch 182/500
# 34/34 - 0s - loss: 0.5038 - accuracy: 0.7406 - val_loss: 1.1549 - val_accuracy: 0.3667
# Epoch 183/500
# 34/34 - 0s - loss: 0.4693 - accuracy: 0.7707 - val_loss: 1.2852 - val_accuracy: 0.3667

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('validation accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#estimator.model.save('.')
# Out:
# INFO:tensorflow:Assets written to: .\assets

# %% [markdown]
# Now the model is being tested against the entire dataset and presented in the form of confusion matrix (matrix [i][j], where i is the label, and j is the prediction).

# %%
preds = estimator.predict(X_scaled)
# Out:
# C:\Users\Matik\.virtualenvs\esportslabGrenadeClassifier-3kXZWbFs\lib\site-packages\tensorflow\python\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y, preds)
# Out:
# array([[ 90,  61],
#        [113, 460]], dtype=int64)

# %% [markdown]
# The results aren't bad, considering the amount and characteristics of data. About 60% of invalid grenades are properly classified, and about 80% of valid grenades are properly classified. The total accuracy is about 76%.

# %% [markdown]
# Below are results of testing the model on train data.

# %%
preds = estimator.predict(X_even)
confusion_matrix(Y_even, preds)
# Out:
# C:\Users\Matik\.virtualenvs\esportslabGrenadeClassifier-3kXZWbFs\lib\site-packages\tensorflow\python\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# array([[ 83,  53],
#        [ 16, 144]], dtype=int64)
